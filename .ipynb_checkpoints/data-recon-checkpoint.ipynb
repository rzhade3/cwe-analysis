# %%
import json
import os

import numpy as np

# %%
# Lets count how much data we have!
verified_directory = 'advisories/github-reviewed'
community_directory = 'advisories/unreviewed'

verified_count = 0
community_count = 0
for root, dirs, files in os.walk(verified_directory):
    verified_count += len(files)
for root, dirs, files in os.walk(community_directory):
    community_count += len(files)

print(f"Verified: {verified_count}")
print(f"Community: {community_count}")
print(f"Total: {verified_count + community_count}")
# Out:
# Verified: 20375
# Community: 231666
# Total: 252041

# %%
directory = 'advisories/github-reviewed'

cwes = np.array([])
for root, dirs, files in os.walk(directory):
    for file in files:
        # If the file is a JSON, then we want to print the path
        if not file.endswith('.json'):
            continue
        with open(os.path.join(root, file), 'r') as f:
            data = json.load(f)
            cwes = np.append(cwes, data['database_specific']['cwe_ids'])

# %%
# Do some preprocessing to strip the `CWE-` prefix
for i in range(len(cwes)):
    cwes[i] = cwes[i].replace('CWE-', '')

# %%
unique, counts = np.unique(cwes, return_counts=True)
print(max(counts))
dict(zip(unique, counts))
# Out:
# 21810
# 3280
# {np.str_('1004'): np.int64(5),
#  np.str_('1021'): np.int64(15),
#  np.str_('1022'): np.int64(5),
#  np.str_('1024'): np.int64(1),
#  np.str_('1038'): np.int64(1),
#  np.str_('1047'): np.int64(1),
#  np.str_('1049'): np.int64(1),
#  np.str_('1050'): np.int64(2),
#  np.str_('1056'): np.int64(1),
#  np.str_('1068'): np.int64(2),
#  np.str_('1088'): np.int64(1),
#  np.str_('1100'): np.int64(1),
#  np.str_('1103'): np.int64(1),
#  np.str_('1104'): np.int64(5),
#  np.str_('1119'): np.int64(1),
#  np.str_('112'): np.int64(4),
#  np.str_('1125'): np.int64(2),
#  np.str_('113'): np.int64(18),
#  np.str_('115'): np.int64(7),
#  np.str_('116'): np.int64(65),
#  np.str_('117'): np.int64(15),
#  np.str_('1188'): np.int64(22),
#  np.str_('119'): np.int64(184),
#  np.str_('12'): np.int64(2),
#  np.str_('120'): np.int64(67),
#  np.str_('121'): np.int64(14),
#  np.str_('122'): np.int64(19),
#  np.str_('1220'): np.int64(12),
#  np.str_('1230'): np.int64(1),
#  np.str_('1236'): np.int64(23),
#  np.str_('124'): np.int64(1),
#  np.str_('1240'): np.int64(3),
#  np.str_('1241'): np.int64(2),
#  np.str_('125'): np.int64(161),
#  np.str_('1254'): np.int64(2),
#  np.str_('1255'): np.int64(1),
#  np.str_('1256'): np.int64(1),
#  np.str_('1258'): np.int64(2),
#  np.str_('1259'): np.int64(3),
#  np.str_('126'): np.int64(5),
#  np.str_('127'): np.int64(1),
#  np.str_('1270'): np.int64(1),
#  np.str_('1283'): np.int64(1),
#  np.str_('1284'): np.int64(25),
#  np.str_('1285'): np.int64(1),
#  np.str_('1286'): np.int64(4),
#  np.str_('1287'): np.int64(5),
#  np.str_('1288'): np.int64(2),
#  np.str_('1289'): np.int64(1),
#  np.str_('129'): np.int64(21),
#  np.str_('1295'): np.int64(3),
#  np.str_('130'): np.int64(17),
#  np.str_('131'): np.int64(15),
#  np.str_('1310'): np.int64(1),
#  np.str_('1321'): np.int64(360),
#  np.str_('1327'): np.int64(1),
#  np.str_('1333'): np.int64(203),
#  np.str_('1336'): np.int64(24),
#  np.str_('134'): np.int64(16),
#  np.str_('1385'): np.int64(2),
#  np.str_('1386'): np.int64(1),
#  np.str_('1390'): np.int64(1),
#  np.str_('1391'): np.int64(4),
#  np.str_('1392'): np.int64(1),
#  np.str_('1395'): np.int64(13),
#  np.str_('140'): np.int64(2),
#  np.str_('144'): np.int64(1),
#  np.str_('147'): np.int64(1),
#  np.str_('148'): np.int64(1),
#  np.str_('149'): np.int64(1),
#  np.str_('15'): np.int64(3),
#  np.str_('150'): np.int64(11),
#  np.str_('154'): np.int64(1),
#  np.str_('155'): np.int64(2),
#  np.str_('172'): np.int64(6),
#  np.str_('173'): np.int64(4),
#  np.str_('176'): np.int64(2),
#  np.str_('177'): np.int64(4),
#  np.str_('178'): np.int64(10),
#  np.str_('180'): np.int64(1),
#  np.str_('183'): np.int64(4),
#  np.str_('184'): np.int64(17),
#  np.str_('185'): np.int64(13),
#  np.str_('187'): np.int64(1),
#  np.str_('188'): np.int64(3),
#  np.str_('190'): np.int64(101),
#  np.str_('191'): np.int64(7),
#  np.str_('193'): np.int64(9),
#  np.str_('195'): np.int64(2),
#  np.str_('196'): np.int64(1),
#  np.str_('197'): np.int64(1),
#  np.str_('198'): np.int64(1),
#  np.str_('20'): np.int64(961),
#  np.str_('200'): np.int64(964),
#  np.str_('201'): np.int64(19),
#  np.str_('202'): np.int64(1),
#  np.str_('203'): np.int64(89),
#  np.str_('204'): np.int64(17),
#  np.str_('208'): np.int64(58),
#  np.str_('209'): np.int64(76),
#  np.str_('212'): np.int64(22),
#  np.str_('213'): np.int64(4),
#  np.str_('214'): np.int64(2),
#  np.str_('215'): np.int64(3),
#  np.str_('22'): np.int64(1019),
#  np.str_('226'): np.int64(5),
#  np.str_('228'): np.int64(2),
#  np.str_('229'): np.int64(1),
#  np.str_('23'): np.int64(34),
#  np.str_('230'): np.int64(1),
#  np.str_('231'): np.int64(2),
#  np.str_('232'): np.int64(2),
#  np.str_('233'): np.int64(7),
#  np.str_('235'): np.int64(1),
#  np.str_('237'): np.int64(1),
#  np.str_('24'): np.int64(5),
#  np.str_('240'): np.int64(1),
#  np.str_('241'): np.int64(8),
#  np.str_('242'): np.int64(2),
#  np.str_('248'): np.int64(41),
#  np.str_('250'): np.int64(13),
#  np.str_('252'): np.int64(13),
#  np.str_('253'): np.int64(3),
#  np.str_('256'): np.int64(71),
#  np.str_('257'): np.int64(1),
#  np.str_('26'): np.int64(1),
#  np.str_('260'): np.int64(1),
#  np.str_('261'): np.int64(1),
#  np.str_('263'): np.int64(1),
#  np.str_('266'): np.int64(19),
#  np.str_('267'): np.int64(4),
#  np.str_('268'): np.int64(3),
#  np.str_('269'): np.int64(230),
#  np.str_('27'): np.int64(2),
#  np.str_('270'): np.int64(7),
#  np.str_('273'): np.int64(4),
#  np.str_('274'): np.int64(3),
#  np.str_('276'): np.int64(90),
#  np.str_('277'): np.int64(5),
#  np.str_('278'): np.int64(2),
#  np.str_('279'): np.int64(3),
#  np.str_('280'): np.int64(16),
#  np.str_('281'): np.int64(42),
#  np.str_('283'): np.int64(2),
#  np.str_('284'): np.int64(358),
#  np.str_('285'): np.int64(166),
#  np.str_('286'): np.int64(1),
#  np.str_('287'): np.int64(406),
#  np.str_('288'): np.int64(16),
#  np.str_('289'): np.int64(3),
#  np.str_('29'): np.int64(23),
#  np.str_('290'): np.int64(41),
#  np.str_('291'): np.int64(1),
#  np.str_('294'): np.int64(18),
#  np.str_('295'): np.int64(189),
#  np.str_('297'): np.int64(13),
#  np.str_('298'): np.int64(2),
#  np.str_('300'): np.int64(9),
#  np.str_('302'): np.int64(3),
#  np.str_('303'): np.int64(7),
#  np.str_('304'): np.int64(6),
#  np.str_('305'): np.int64(16),
#  np.str_('306'): np.int64(66),
#  np.str_('307'): np.int64(40),
#  np.str_('308'): np.int64(1),
#  np.str_('309'): np.int64(1),
#  np.str_('31'): np.int64(3),
#  np.str_('311'): np.int64(213),
#  np.str_('312'): np.int64(78),
#  np.str_('313'): np.int64(1),
#  np.str_('315'): np.int64(2),
#  np.str_('318'): np.int64(1),
#  np.str_('319'): np.int64(75),
#  np.str_('321'): np.int64(10),
#  np.str_('322'): np.int64(6),
#  np.str_('323'): np.int64(6),
#  np.str_('324'): np.int64(6),
#  np.str_('325'): np.int64(7),
#  np.str_('326'): np.int64(43),
#  np.str_('327'): np.int64(77),
#  np.str_('328'): np.int64(10),
#  np.str_('329'): np.int64(1),
#  np.str_('330'): np.int64(59),
#  np.str_('331'): np.int64(28),
#  np.str_('332'): np.int64(4),
#  np.str_('335'): np.int64(4),
#  np.str_('336'): np.int64(1),
#  np.str_('337'): np.int64(2),
#  np.str_('338'): np.int64(27),
#  np.str_('34'): np.int64(1),
#  np.str_('340'): np.int64(5),
#  np.str_('341'): np.int64(1),
#  np.str_('344'): np.int64(1),
#  np.str_('345'): np.int64(75),
#  np.str_('346'): np.int64(41),
#  np.str_('347'): np.int64(141),
#  np.str_('348'): np.int64(4),
#  np.str_('349'): np.int64(9),
#  np.str_('35'): np.int64(9),
#  np.str_('350'): np.int64(7),
#  np.str_('351'): np.int64(1),
#  np.str_('352'): np.int64(695),
#  np.str_('354'): np.int64(18),
#  np.str_('358'): np.int64(9),
#  np.str_('359'): np.int64(19),
#  np.str_('36'): np.int64(7),
#  np.str_('362'): np.int64(150),
#  np.str_('363'): np.int64(2),
#  np.str_('365'): np.int64(1),
#  np.str_('366'): np.int64(4),
#  np.str_('367'): np.int64(28),
#  np.str_('369'): np.int64(63),
#  np.str_('372'): np.int64(2),
#  np.str_('377'): np.int64(33),
#  np.str_('378'): np.int64(14),
#  np.str_('379'): np.int64(16),
#  np.str_('384'): np.int64(85),
#  np.str_('385'): np.int64(7),
#  np.str_('391'): np.int64(3),
#  np.str_('392'): np.int64(3),
#  np.str_('393'): np.int64(1),
#  np.str_('394'): np.int64(1),
#  np.str_('395'): np.int64(1),
#  np.str_('40'): np.int64(1),
#  np.str_('400'): np.int64(797),
#  np.str_('401'): np.int64(28),
#  np.str_('402'): np.int64(6),
#  np.str_('403'): np.int64(1),
#  np.str_('404'): np.int64(18),
#  np.str_('405'): np.int64(4),
#  np.str_('406'): np.int64(1),
#  np.str_('407'): np.int64(10),
#  np.str_('408'): np.int64(1),
#  np.str_('409'): np.int64(8),
#  np.str_('41'): np.int64(1),
#  np.str_('410'): np.int64(1),
#  np.str_('415'): np.int64(37),
#  np.str_('416'): np.int64(85),
#  np.str_('42'): np.int64(1),
#  np.str_('420'): np.int64(5),
#  np.str_('425'): np.int64(10),
#  np.str_('426'): np.int64(20),
#  np.str_('427'): np.int64(17),
#  np.str_('428'): np.int64(2),
#  np.str_('433'): np.int64(3),
#  np.str_('434'): np.int64(239),
#  np.str_('435'): np.int64(3),
#  np.str_('436'): np.int64(22),
#  np.str_('437'): np.int64(1),
#  np.str_('440'): np.int64(8),
#  np.str_('441'): np.int64(6),
#  np.str_('444'): np.int64(94),
#  np.str_('451'): np.int64(1),
#  np.str_('453'): np.int64(4),
#  np.str_('457'): np.int64(4),
#  np.str_('459'): np.int64(12),
#  np.str_('460'): np.int64(2),
#  np.str_('466'): np.int64(1),
#  np.str_('470'): np.int64(11),
#  np.str_('471'): np.int64(18),
#  np.str_('472'): np.int64(3),
#  np.str_('475'): np.int64(3),
#  np.str_('476'): np.int64(126),
#  np.str_('480'): np.int64(1),
#  np.str_('488'): np.int64(3),
#  np.str_('489'): np.int64(1),
#  np.str_('494'): np.int64(14),
#  np.str_('497'): np.int64(3),
#  np.str_('50'): np.int64(1),
#  np.str_('501'): np.int64(5),
#  np.str_('502'): np.int64(512),
#  np.str_('506'): np.int64(378),
#  np.str_('509'): np.int64(1),
#  np.str_('520'): np.int64(1),
#  np.str_('521'): np.int64(20),
#  np.str_('522'): np.int64(225),
#  np.str_('523'): np.int64(2),
#  np.str_('524'): np.int64(6),
#  np.str_('525'): np.int64(4),
#  np.str_('526'): np.int64(4),
#  np.str_('527'): np.int64(1),
#  np.str_('532'): np.int64(144),
#  np.str_('538'): np.int64(7),
#  np.str_('539'): np.int64(1),
#  np.str_('544'): np.int64(2),
#  np.str_('547'): np.int64(3),
#  np.str_('548'): np.int64(5),
#  np.str_('549'): np.int64(2),
#  np.str_('551'): np.int64(4),
#  np.str_('552'): np.int64(47),
#  np.str_('565'): np.int64(9),
#  np.str_('566'): np.int64(1),
#  np.str_('567'): np.int64(1),
#  np.str_('59'): np.int64(103),
#  np.str_('590'): np.int64(1),
#  np.str_('595'): np.int64(1),
#  np.str_('598'): np.int64(4),
#  np.str_('599'): np.int64(3),
#  np.str_('6'): np.int64(1),
#  np.str_('601'): np.int64(268),
#  np.str_('602'): np.int64(3),
#  np.str_('606'): np.int64(3),
#  np.str_('61'): np.int64(10),
#  np.str_('610'): np.int64(22),
#  np.str_('611'): np.int64(313),
#  np.str_('612'): np.int64(2),
#  np.str_('613'): np.int64(87),
#  np.str_('614'): np.int64(10),
#  np.str_('617'): np.int64(74),
#  np.str_('62'): np.int64(1),
#  np.str_('620'): np.int64(5),
#  np.str_('621'): np.int64(1),
#  np.str_('624'): np.int64(1),
#  np.str_('625'): np.int64(1),
#  np.str_('627'): np.int64(1),
#  np.str_('636'): np.int64(4),
#  np.str_('639'): np.int64(90),
#  np.str_('64'): np.int64(5),
#  np.str_('640'): np.int64(24),
#  np.str_('641'): np.int64(3),
#  np.str_('642'): np.int64(1),
#  np.str_('644'): np.int64(4),
#  np.str_('645'): np.int64(1),
#  np.str_('648'): np.int64(6),
#  np.str_('649'): np.int64(1),
#  np.str_('653'): np.int64(2),
#  np.str_('657'): np.int64(7),
#  np.str_('662'): np.int64(20),
#  np.str_('664'): np.int64(4),
#  np.str_('665'): np.int64(21),
#  np.str_('667'): np.int64(9),
#  np.str_('668'): np.int64(145),
#  np.str_('669'): np.int64(11),
#  np.str_('67'): np.int64(1),
#  np.str_('670'): np.int64(31),
#  np.str_('672'): np.int64(11),
#  np.str_('673'): np.int64(2),
#  np.str_('674'): np.int64(56),
#  np.str_('675'): np.int64(1),
#  np.str_('676'): np.int64(1),
#  np.str_('680'): np.int64(1),
#  np.str_('681'): np.int64(15),
#  np.str_('682'): np.int64(24),
#  np.str_('683'): np.int64(1),
#  np.str_('684'): np.int64(1),
#  np.str_('690'): np.int64(5),
#  np.str_('692'): np.int64(1),
#  np.str_('693'): np.int64(68),
#  np.str_('694'): np.int64(2),
#  np.str_('696'): np.int64(8),
#  np.str_('697'): np.int64(43),
#  np.str_('703'): np.int64(13),
#  np.str_('704'): np.int64(20),
#  np.str_('706'): np.int64(13),
#  np.str_('707'): np.int64(4),
#  np.str_('73'): np.int64(21),
#  np.str_('732'): np.int64(125),
#  np.str_('733'): np.int64(1),
#  np.str_('74'): np.int64(339),
#  np.str_('749'): np.int64(8),
#  np.str_('75'): np.int64(13),
#  np.str_('754'): np.int64(57),
#  np.str_('755'): np.int64(60),
#  np.str_('756'): np.int64(1),
#  np.str_('757'): np.int64(1),
#  np.str_('758'): np.int64(2),
#  np.str_('76'): np.int64(3),
#  np.str_('763'): np.int64(1),
#  np.str_('77'): np.int64(315),
#  np.str_('770'): np.int64(232),
#  np.str_('772'): np.int64(15),
#  np.str_('776'): np.int64(47),
#  np.str_('778'): np.int64(1),
#  np.str_('779'): np.int64(1),
#  np.str_('78'): np.int64(334),
#  np.str_('784'): np.int64(1),
#  np.str_('787'): np.int64(388),
#  np.str_('788'): np.int64(1),
#  np.str_('789'): np.int64(20),
#  np.str_('79'): np.int64(3280),
#  np.str_('790'): np.int64(2),
#  np.str_('791'): np.int64(2),
#  np.str_('798'): np.int64(32),
#  np.str_('799'): np.int64(2),
#  np.str_('80'): np.int64(71),
#  np.str_('804'): np.int64(1),
#  np.str_('807'): np.int64(5),
#  np.str_('81'): np.int64(4),
#  np.str_('820'): np.int64(3),
#  np.str_('824'): np.int64(19),
#  np.str_('825'): np.int64(1),
#  np.str_('826'): np.int64(1),
#  np.str_('829'): np.int64(23),
#  np.str_('83'): np.int64(3),
#  np.str_('830'): np.int64(1),
#  np.str_('833'): np.int64(1),
#  np.str_('834'): np.int64(14),
#  np.str_('835'): np.int64(114),
#  np.str_('837'): np.int64(2),
#  np.str_('838'): np.int64(4),
#  np.str_('841'): np.int64(5),
#  np.str_('842'): np.int64(3),
#  np.str_('843'): np.int64(50),
#  np.str_('86'): np.int64(2),
#  np.str_('862'): np.int64(409),
#  np.str_('863'): np.int64(379),
#  np.str_('87'): np.int64(10),
#  np.str_('88'): np.int64(48),
#  np.str_('89'): np.int64(469),
#  np.str_('90'): np.int64(8),
#  np.str_('908'): np.int64(55),
#  np.str_('909'): np.int64(4),
#  np.str_('91'): np.int64(26),
#  np.str_('912'): np.int64(8),
#  np.str_('913'): np.int64(28),
#  np.str_('914'): np.int64(1),
#  np.str_('915'): np.int64(70),
#  np.str_('916'): np.int64(14),
#  np.str_('917'): np.int64(27),
#  np.str_('918'): np.int64(290),
#  np.str_('920'): np.int64(1),
#  np.str_('921'): np.int64(3),
#  np.str_('922'): np.int64(17),
#  np.str_('923'): np.int64(2),
#  np.str_('924'): np.int64(1),
#  np.str_('926'): np.int64(2),
#  np.str_('927'): np.int64(1),
#  np.str_('93'): np.int64(26),
#  np.str_('94'): np.int64(575),
#  np.str_('940'): np.int64(6),
#  np.str_('941'): np.int64(1),
#  np.str_('942'): np.int64(5),
#  np.str_('943'): np.int64(1),
#  np.str_('95'): np.int64(53),
#  np.str_('96'): np.int64(5),
#  np.str_('97'): np.int64(1),
#  np.str_('98'): np.int64(7),
#  np.str_('99'): np.int64(2)}
